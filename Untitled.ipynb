# %%
import torch # Keep in mind that YOLOv5 runs on top of PyTorch, so we need to import it to the notebook
 
from IPython.display import Image #this is to render predictions
 
#!git clone https://github.com/ultralytics/yolov5 # Use this if you want to keep the official Ultralytics scripts.
 
#!git clone https://github.com/zldrobit/yolov5.git
# %cd yolov5
#!git checkout tf-android
# Out:
# C:\Users\king\Desktop\fog\yolov5

# %%
# !pip install -r requirements.txt
# !pip install tensorflow==2.3.1 #Keep this version of TF as YOLOv5 works well with it.
print('All set. Using PyTorch version %s with %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
# ...
# All set. Using PyTorch version 1.11.0+cpu with CPU
# ERROR: Invalid requirement: '#Keep'

# %%
# !python train.py --img-size 640 --batch 16 --epochs 30 --data dataset.yaml --weights yolov5s.pt --cache

# %%
# %load_ext tensorboard
# %tensorboard --logdir runs
# Out:
# Reusing TensorBoard on port 6006 (pid 7888), started 3:34:12 ago. (Use '!kill 7888' to kill it.)
#       <iframe id="tensorboard-frame-bb14b8fc2acbf05f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-bb14b8fc2acbf05f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
Image(filename='runs/train/exp/test_batch0_pred.jpg', width=1000)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8500/3903872521.py in <module>
# ----> 1 Image(filename='runs/train/exp/test_batch0_pred.jpg', width=1000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata)
#    1229         self.retina = retina
#    1230         self.unconfined = unconfined
# -> 1231         super(Image, self).__init__(data=data, url=url, filename=filename,
#    1232                 metadata=metadata)
#    1233
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\display.py in __init__(self, data, url, filename, metadata)
#     635             self.metadata = {}
#     636
# --> 637         self.reload()
#     638         self._check_data()
#     639
#
# ...

# %%
# %cd yolov5
# Out:
# [WinError 2] 系统找不到指定的文件。: 'yolov5'
# C:\Users\king\Desktop\content\yolov5
# Namespace(weights=['runs/train/exp6/weights/best.pt'], source='../test_images', img_size=[416, 416], conf_thres=0.4, iou_thres=0.45, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, tfl_int8=False, line_thickness=3, hide_labels=False, hide_conf=False)
# image 1/1 C:\Users\king\Desktop\content\yolov5\..\test_images\zidane.jpg: 256x416 Done. (0.098s)
# Results saved to runs\detect\exp2
# Done. (0.116s)
# YOLOv5  2021-12-16 torch 1.11.0+cpu CPU
#
# Fusing layers...
# ...

# %%
# %cd yolov5
# !python detect.py --weights runs/train/exp/weights/best.pt  --conf 0.1 --iou 0.1  --classes  1 --save-crop --source 0
# Out:
# [WinError 2] 系统找不到指定的文件。: 'yolov5'
# C:\Users\king\Desktop\content\yolov5
# Namespace(weights=['runs/train/exp/weights/best.pt'], source='0', img_size=[320, 320], conf_thres=0.1, iou_thres=0.1, max_det=1000, device='', view_img=False, save_txt=False, save_conf=False, save_crop=True, nosave=False, classes=[1], agnostic_nms=False, augment=False, update=False, project='runs/detect', name='exp', exist_ok=False, tfl_int8=False, line_thickness=3, hide_labels=False, hide_conf=False)
# YOLOv5  2021-12-16 torch 1.11.0+cpu CPU
#
# Fusing layers...
# C:\ProgramData\Anaconda3\lib\site-packages\torch\functional.py:568: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  C:\actions-runner\_work\pytorch\pytorch\builder\windows\pytorch\aten\src\ATen\native\TensorShape.cpp:2228.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# ...

# %%
#Detection results were saved at runs/detect/exp2, let's explore the output.
# !ls runs/detect/exp11
# Out:
# R-C.jpg
# bus.jpg
# zidane.jpg

# %%
#Plotting the first image
Image(filename='runs/detect/exp11/zidane.jpg', width=415)

# %%
Image(filename='runs/detect/exp11/R-C.jpg', width=415)

# %%
Image(filename='runs/detect/exp11/bus.jpg', width=415)

# %%
import tensorflow as tf
print(tf.__version__)
# !PYTHONPATH=. python3 /content/yolov5/models/tf.py --weight /content/yolov5/runs/train/exp6/weights/best.pt --cfg models/yolov5s.yaml --img 416 --source /content/FaceMaskDataset/images/train
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8128/922529485.py in <module>
# ----> 1 import tensorflow as tf
#       2 print(tf.__version__)
#       3 get_ipython().system('PYTHONPATH=. python3 /content/yolov5/models/tf.py --weight /content/yolov5/runs/train/exp6/weights/best.pt --cfg models/yolov5s.yaml --img 416 --source /content/FaceMaskDataset/images/train')
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt  --conf 0.1 --iou 0.1 --source 0 --classes 0 1
